# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# Load your data into a DataFrame
df = pd.read_csv('03_Library Systembook.csv')

# Remove rows with any empty cells
df.dropna(inplace=True)

df.head(n=20)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
import pandas as pd

# Load your data into a DataFrame
df = pd.read_csv('03_Library Systembook.csv')

# Replace NaN values with a specific value (e.g., 0)
df.dropna(inplace=True)

df.head())
# Out:
#   Cell In[15], line 9
#     df.head())
#              ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd

# Load your data into a DataFrame
df = pd.read_csv('03_Library Systembook.csv')

# Replace NaN values with a specific value (e.g., 0)
df.fillna(0, inplace=True)

df.head(n=20)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
dfhead
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dfhead
#
# NameError: name 'dfhead' is not defined

# %%
import pandas as pd

# Load your data into a DataFrame
df = pd.read_csv('03_Library Systembook.csv')

# Remove double quotes from the 'date' column
df['date'] = df['date'].str.replace('"', '')

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 7
#       4 df = pd.read_csv('03_Library Systembook.csv')
# ...

# %%
import pandas as pd

# Load your data into a DataFrame
df = pd.read_csv('03_Library Systembook.csv')

# Remove double quotes from the 'date' column
df['Book checkout'] = df['date'].str.replace('"', '')

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 7
#       4 df = pd.read_csv('03_Library Systembook.csv')
# ...

# %%
import pandas as pd

# Load your data into a DataFrame
df = pd.read_csv('03_Library Systembook.csv')

# Remove leading and trailing double quotes from the 'date' column
df['Book checkout'] = df['Book checkout'].str.strip('"')

df.head(n=20)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        IT    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East of Eden    30/04/2023
# ...

# %%
import pandas as pd

# Load the original CSV
df = pd.read_csv("03_Library Systembook.csv")

# Save to a new CSV
df.to_csv("Cleaned_Books.csv", index=False)

print("Cleaned file saved as 'Cleaned_Books.csv'")
# Out:
# Cleaned file saved as 'Cleaned_Books.csv'

# %%
pip install sqlalchemy pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd

# Replace with your actual database connection details
server = 'localhost'
database = 'your_database'
username = 'your_student07\admin'
password = 'your_password'
driver = 'ODBC Driver 17 for SQL Server'

connection_string = f'mssql+pyodbc://{username}:{password}@{server}/{database}?driver={driver}'
engine = create_engine(connection_string)
